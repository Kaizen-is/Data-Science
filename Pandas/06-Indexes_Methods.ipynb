# %% [markdown]
# ###Data Science and AI Practicum
# - Index Modules

# %%
import pandas as pd
data = {"Network Security": {"Firewall": {"definition": "Monitors and controls network traffic.","types":"Hardware"},
       "VPN": {"definition": "Creates a secure connection over the internet.","protocols": "OpenVPN"}}}

df = pd.DataFrame(data)
df
# Out:
#                                              Network Security  \
# Firewall    {'definition': 'Monitors and controls network ...
# VPN         {'definition': 'Creates a secure connection ov...
# Phishing                                                  NaN
# Ransomware                                                NaN
#
#                                                  Attack Types
# Firewall                                                  NaN
# VPN                                                       NaN
# Phishing    {'definition': 'Tricks users into revealing se...
# Ransomware  {'definition': 'Encrypts data and demands paym...

# %%
import pandas as pd
data2 = {"Attack Types": {"Phishing": {"definition": "Tricks users into revealing sensitive information.","methods": "Email"},
       "Ransomware": {"definition": "Encrypts data and demands payment for decryption.","examples": "WannaCry"}}}
df2 = pd.DataFrame(data2)
df2
# Out:
#                                                  Attack Types
# Phishing    {'definition': 'Tricks users into revealing se...
# Ransomware  {'definition': 'Encrypts data and demands paym...

# %%
df.index
# Out:
# Index(['Firewall', 'VPN', 'Phishing', 'Ransomware'], dtype='object')

# %%
df.T
# Out:
#                                                            Firewall  \
# Network Security  {'definition': 'Monitors and controls network ...
# Attack Types                                                    NaN
#
#                                                                 VPN  \
# Network Security  {'definition': 'Creates a secure connection ov...
# Attack Types                                                    NaN
#
#                                                            Phishing  \
# Network Security                                                NaN
# Attack Types      {'definition': 'Tricks users into revealing se...
#
#                                                          Ransomware
# Network Security                                                NaN
# Attack Types      {'definition': 'Encrypts data and demands paym...

# %%
df.columns
# Out:
# Index(['Network Security', 'Attack Types'], dtype='object')

# %%
indexes = df.columns
'Temp' in indexes
# Out:
# False

# %%
indexes = df.columns
'Attack Types' in indexes
# Out:
# True

# %%
columns = df2.columns
columns
# Out:
# Index(['Attack Types'], dtype='object')

# %%
indexes[0] = 'Makima' #does not work
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-c7dc1c8fc4b3> in <cell line: 0>()
# ----> 1 indexes[0] = 'Makima'
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in __setitem__(self, key, value)
#    5369     @final
#    5370     def __setitem__(self, key, value) -> None:
# -> 5371         raise TypeError("Index does not support mutable operations")
#    5372
#    5373     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %%
indexes[1:3]
# Out:
# Index(['Attack Types'], dtype='object')

# %% [markdown]
# - Methods

# %%
import pandas as pd
info = {'Kaizen':{'age':17, 'major':'DataAnalysis', 'city':'Vien'},
        'Jinwoo':{'age':18, 'major':'Datascience', 'city':'Tokyo'}}
infodf = pd.DataFrame(info)
infodf.index.name = 'PersonalInf'
infodf
# Out:
#                    Kaizen       Jinwoo
# PersonalInf
# age                    17           18
# major        DataAnalysis  Datascience
# city                 Vien        Tokyo

# %%
import pandas as pd
info2 = {'Aki':{'age':18, 'major':'AI Researcher', 'city':'NewYork'},
        'Baki':{'age':19, 'major':'ML engeneer', 'city':'Tokyo'}}
infodf2 = pd.DataFrame(info2)

# %%
infodf3 = pd.concat([infodf, infodf2])
infodf3
# Out:
#                        Aki         Baki
# PersonalInf
# age                     18           19
# major        AI Researcher  ML engeneer
# city               NewYork        Tokyo
# age                     18           19
# major        AI Researcher  ML engeneer
# city               NewYork        Tokyo

# %%
infodf3.index
# Out:
# Index(['age', 'major', 'city', 'age', 'major', 'city'], dtype='object', name='PersonalInf')

# %%
newindex = pd.Index(['age', 'year', 'food'])
newindex
# Out:
# Index(['age', 'year', 'food'], dtype='object')

# %%
newindex.isin(infodf3.index)
# Out:
# array([ True, False, False])

# %%
infodf3.index.difference
# Out:
# <bound method Index.difference of Index(['age', 'major', 'city', 'age', 'major', 'city'], dtype='object', name='PersonalInf')>

# %%
infodf3.index.difference(newindex)
# Out:
# Index(['city', 'major'], dtype='object')

# %%
newindex.difference(infodf3.index)
# Out:
# Index(['food', 'year'], dtype='object')

# %%
infodf3.index.union(newindex)
# Out:
# Index(['age', 'age', 'city', 'city', 'food', 'major', 'major', 'year'], dtype='object')

# %%
newindex.union(infodf3)
# Out:
# <ipython-input-52-61a33708325f>:1: RuntimeWarning: '<' not supported between instances of 'str' and 'int', sort order is undefined for incomparable objects.
#   newindex.union(infodf3)
# <ipython-input-52-61a33708325f>:1: RuntimeWarning: '<' not supported between instances of 'str' and 'int', sort order is undefined for incomparable objects.
#   newindex.union(infodf3)
# Index([                           'age',                           'year',
#                                  'food',                         (18, 19),
#                                (18, 19), ('AI Researcher', 'ML engeneer'),
#        ('AI Researcher', 'ML engeneer'),             ('NewYork', 'Tokyo'),
#                    ('NewYork', 'Tokyo')],
#       dtype='object')

# %%
infodf3.index
infodf3.index.delete(2)
# Out:
# Index(['age', 'major', 'age', 'major', 'city'], dtype='object', name='PersonalInf')

# %%
infodf3.index
infodf3.index.drop('age')
# Out:
# Index(['major', 'city', 'major', 'city'], dtype='object', name='PersonalInf')
