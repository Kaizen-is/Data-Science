# %% [markdown]
# ### Data Science and AI Practicum

# %% [markdown]
# ### Data Set statistics

# %%
import pandas as pd
import numpy as np

uz = {2020:35.4, 2021:36.1, 2022:37.2, 2023:40, 2024:42, 2015:44}
ka = {2020:32.4, 2021:33.1, 2022:34.2, 2023:40, 2024:32.2, 2015:34}
ta = {2020:44.4, 2021:42.7, 2022:45.3, 2023:46.3, 2024:48, 2015:50}
tu = {2020:63.4, 2021:65.1, 2022:70.2, 2023:70.5, 2024:72.3, 2015:77}

df = pd.DataFrame(
    {"Uzbekistan":uz,
     "Kazaxistan":ka,
     "Tadjikistan":ta,
     "Turkmenistan":tu}
)
df
# Out:
#       Uzbekistan  Kazaxistan  Tadjikistan  Turkmenistan
# 2020        35.4        32.4         44.4          63.4
# 2021        36.1        33.1         42.7          65.1
# 2022        37.2        34.2         45.3          70.2
# 2023        40.0        40.0         46.3          70.5
# 2024        42.0        32.2         48.0          72.3
# 2015        44.0        34.0         50.0          77.0

# %%
df.sum() # sum for all Countries
# Out:
# Uzbekistan      234.7
# Kazaxistan      205.9
# Tadjikistan     276.7
# Turkmenistan    418.5
# dtype: float64

# %%
df.sum(axis = 1) # sum for years
# Out:
# 2020    175.6
# 2021    177.0
# 2022    186.9
# 2023    196.8
# 2024    194.5
# 2015    205.0
# dtype: float64

# %%
df2 = df.T
# Out:
#               2020  2021  2022  2023  2024  2015
# Uzbekistan    35.4  36.1  37.2  40.0  42.0  44.0
# Kazaxistan    32.4  33.1  34.2  40.0  32.2  34.0
# Tadjikistan   44.4  42.7  45.3  46.3  48.0  50.0
# Turkmenistan  63.4  65.1  70.2  70.5  72.3  77.0

# %%
df2.sum()
# Out:
# 2020    175.6
# 2021    177.0
# 2022    186.9
# 2023    196.8
# 2024    194.5
# 2015    205.0
# dtype: float64

# %%
df2.sum(axis = 1)
# Out:
# Uzbekistan      234.7
# Kazaxistan      205.9
# Tadjikistan     276.7
# Turkmenistan    418.5
# dtype: float64

# %%
df.mean(axis = 1)
# Out:
# 2020    43.900
# 2021    44.250
# 2022    46.725
# 2023    49.200
# 2024    48.625
# 2015    51.250
# dtype: float64

# %%
df.mean()
# Out:
# Uzbekistan      39.116667
# Kazaxistan      34.316667
# Tadjikistan     46.116667
# Turkmenistan    69.750000
# dtype: float64

# %%
df.prod()
# Out:
# Uzbekistan      3.514110e+09
# Kazaxistan      1.606179e+09
# Tadjikistan     9.543359e+09
# Turkmenistan    1.137170e+11
# dtype: float64

# %% [markdown]
# `idxmax()` `idxmin()`

# %%
df2
# Out:
#               2020  2021  2022  2023  2024  2015
# Uzbekistan    35.4  36.1  37.2  40.0  42.0  44.0
# Kazaxistan    32.4  33.1  34.2  40.0  32.2  34.0
# Tadjikistan   44.4  42.7  45.3  46.3  48.0  50.0
# Turkmenistan  63.4  65.1  70.2  70.5  72.3  77.0

# %%
df2[2023].idxmax()
# Out:
# 'Turkmenistan'

# %%
df2[2020].idxmin()
# Out:
# 'Kazaxistan'

# %%
df2[2023].argmax()
# Out:
# np.int64(3)

# %%
df2.iloc[3]
# Out:
# 2020    63.4
# 2021    65.1
# 2022    70.2
# 2023    70.5
# 2024    72.3
# 2015    77.0
# Name: Turkmenistan, dtype: float64

# %%
df2[2020].argmin()
# Out:
# np.int64(1)

# %%
df2.iloc[1]
# Out:
# 2020    32.4
# 2021    33.1
# 2022    34.2
# 2023    40.0
# 2024    32.2
# 2015    34.0
# Name: Kazaxistan, dtype: float64

# %%
df
# Out:
#       Uzbekistan  Kazaxistan  Tadjikistan  Turkmenistan
# 2020        35.4        32.4         44.4          63.4
# 2021        36.1        33.1         42.7          65.1
# 2022        37.2        34.2         45.3          70.2
# 2023        40.0        40.0         46.3          70.5
# 2024        42.0        32.2         48.0          72.3
# 2015        44.0        34.0         50.0          77.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, 2020 to 2015
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Uzbekistan    6 non-null      float64
#  1   Kazaxistan    6 non-null      float64
#  2   Tadjikistan   6 non-null      float64
#  3   Turkmenistan  6 non-null      float64
# dtypes: float64(4)
# memory usage: 412.0 bytes

# %%
df.describe()
# Out:
#        Uzbekistan  Kazaxistan  Tadjikistan  Turkmenistan
# count    6.000000    6.000000     6.000000      6.000000
# mean    39.116667   34.316667    46.116667     69.750000
# std      3.450459    2.899943     2.605699      4.935079
# min     35.400000   32.200000    42.700000     63.400000
# 25%     36.375000   32.575000    44.625000     66.375000
# 50%     38.600000   33.550000    45.800000     70.350000
# 75%     41.500000   34.150000    47.575000     71.850000
# max     44.000000   40.000000    50.000000     77.000000

# %%
df['Uzbekistan'].plot.hist(bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Turkmenistan'].plot.hist(bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
city = {'Name':['Vien', 'NewYork', 'Tashkent', 'Namangan', 'Parice'],
        'Year':[2010, 2015, 2016, 2017, 2018],
        'Quantity':[56000, 34000, 23000, 65000, 87000],
        'Temp':[1.56, 1.45, 1.45, 1.53, 1.87]}

city = pd.DataFrame(city)
city
# Out:
#        Name  Year  Quantity  Temp
# 0      Vien  2010     56000  1.56
# 1   NewYork  2015     34000  1.45
# 2  Tashkent  2016     23000  1.45
# 3  Namangan  2017     65000  1.53
# 4    Parice  2018     87000  1.87

# %%
city.describe()
# Out:
#               Year      Quantity      Temp
# count     5.000000      5.000000  5.000000
# mean   2015.200000  53000.000000  1.572000
# std       3.114482  25347.583711  0.173551
# min    2010.000000  23000.000000  1.450000
# 25%    2015.000000  34000.000000  1.450000
# 50%    2016.000000  56000.000000  1.530000
# 75%    2017.000000  65000.000000  1.560000
# max    2018.000000  87000.000000  1.870000

# %%
city['Temp'].plot.hist(bins=30)
# Out:
# <Axes: ylabel='Frequency'>
