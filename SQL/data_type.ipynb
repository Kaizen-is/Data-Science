# %% [markdown]
# ### SQL Data Types

# %% [markdown]
# `Numeric data types`

# %%
import pandas as pd

data = {
    'Nu_Type':['tinyint', 'smaillint', 'int', 'bigint', 'float(n)', 'real', 'bit'],
    'Value range':['0 to 255', '-32.768 to 32.768', '	-2,147,483,648 to 2,147,483,647', '-2⁶³ to 2⁶³-1', '~±1.5 × 10⁻⁴⁵ to ±3.4 × 10³⁸', '~±1.5 × 10⁻³⁸ to ±3.4 × 10³⁸', '	0 or 1']
}

df = pd.DataFrame(data, index = (1, 2, 3, 4, 5, 6, 7))
df
# Out:
#        Dtype                        Value range
# 1    tinyint                           0 to 255
# 2  smaillint                  -32.768 to 32.768
# 3        int  \t-2,147,483,648 to 2,147,483,647
# 4     bigint                      -2⁶³ to 2⁶³-1
# 5   float(n)       ~±1.5 × 10⁻⁴⁵ to ±3.4 × 10³⁸
# 6       real       ~±1.5 × 10⁻³⁸ to ±3.4 × 10³⁸
# 7        bit                           \t0 or 1

# %% [markdown]
# `character and string dtypes`

# %%
import pandas as pd
txt = {
    'Ch_Type':['char(n)', 'varchar(n)', 'text', 'nchar(n)', 'nvarchar(n)', 'ntext'],
    'Max Length': ['1-8.000', '1-8.000', 'up to 2**31', "1-4.000", '1-4.000', 'up to 2**31']
}
df = pd.DataFrame(txt, index = (1, 2, 3, 4, 5, 6))
df
# Out:
#        Ch_Type   Max Length
# 1      char(n)      1-8.000
# 2   varchar(n)      1-8.000
# 3         text  up to 2**31
# 4     nchar(n)      1-4.000
# 5  nvarchar(n)      1-4.000
# 6        ntext  up to 2**31

# %% [markdown]
# `DATA AND TIME`

# %%
import pandas as pd
date = {
    'dtype':['date', 'time', 'datetime', 'smalldatetime', 'datetime2', 'datetimeoffset'],
    'Format':['YYYY-MM-DD', 'HH:MI:SS.mmm', 'YYYY-MM-DD HH:MI:SS', 'YYYY-MM-DD HH:MI', 'YYYY-MM0DD HH:MI:SS.MMMMMM', 'YYYY-MM-DD HH:MI:SS.mmm']

}

df = pd.DataFrame(date)
df
# Out:
#             dtype                      Format
# 0            date                  YYYY-MM-DD
# 1            time                HH:MI:SS.mmm
# 2        datetime         YYYY-MM-DD HH:MI:SS
# 3   smalldatetime            YYYY-MM-DD HH:MI
# 4       datetime2  YYYY-MM0DD HH:MI:SS.MMMMMM
# 5  datetimeoffset     YYYY-MM-DD HH:MI:SS.mmm
